# %% [markdown]
# # Creando Nombres

# %%
import pandas as pd

# %%
nombres_m = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?sexo=M&qtd=200")
nombres_f = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?sexo=F&qtd=200")

# %%
type(nombres_f)
# Out:
# pandas.core.frame.DataFrame

# %%
print("Cantidade de nombres: " + str(len(nombres_m)+len(nombres_f)))
# Out:
# Cantidade de nombres: 400

# %%
frames = [nombres_m,nombres_f]
frames
# Out:
# [          nome  regiao     freq  rank sexo
#  0         JOSE       0  5732508     1    M
#  1         JOAO       0  2971935     2    M
#  2      ANTONIO       0  2567494     3    M
#  3    FRANCISCO       0  1765197     4    M
#  4       CARLOS       0  1483121     5    M
#  ..         ...     ...      ...   ...  ...
#  195     WALTER       0    67207   196    M
#  196    ARLINDO       0    66669   197    M
#  197    MICHAEL       0    65736   198    M
#  198     ALVARO       0    65444   199    M
#  199    GEOVANE       0    65435   200    M
#
#  [200 rows x 5 columns],
#            nome  regiao      freq  rank sexo
#  0        MARIA       0  11694738     1    F
#  1          ANA       0   3079729     2    F
#  2    FRANCISCA       0    721637     3    F
#  3      ANTONIA       0    588783     4    F
#  4      ADRIANA       0    565621     5    F
#  ..         ...     ...       ...   ...  ...
#  195     ROSANE       0     82203   196    F
#  196    IVONETE       0     81878   197    F
#  197    LUCIANE       0     81230   198    F
#  198    ISADORA       0     81100   199    F
#  199      NILZA       0     80128   200    F
#
#  [200 rows x 5 columns]]

# %%
nombres = pd.concat(frames)['nome'].to_frame()
nombres.columns = ['nombre']
nombres.sample(5)
# Out:
#         nombre
# 92     VALERIA
# 127      TAINA
# 3    FRANCISCO
# 168   CRISTIAN
# 163    REGIANE

# %%
nombres.sample(5)
# Out:
#          nombre
# 107  ELISANGELA
# 163     REGIANE
# 1          JOAO
# 26         RITA
# 113     ROBERTA

# %% [markdown]
# # Incluyendo ID de alumnos

# %%
import numpy as np

# %%
np.random.seed(123)

# %%
total_alumnos = len(nombres)
total_alumnos
# Out:
# 400

# %%
nombres['id_alumno'] = np.random.permutation(total_alumnos) + 1
nombres.sample(5)
# Out:
#        nombre  id_alumno
# 188  VALDECIR        369
# 57       IGOR        303
# 3     ANTONIA        382
# 182   LIDIANE         33
# 30     ELIANE        111

# %%
dominios = ['@dominiodeemail.com','@serviciodeemail.com']

# %%
nombres['dominio'] = np.random.choice(dominios,total_alumnos)
nombres.sample(5)
# Out:
#        nombre  id_alumno               dominio
# 84     FATIMA         78   @dominiodeemail.com
# 0       MARIA        331  @serviciodeemail.com
# 179   LILIANE        340   @dominiodeemail.com
# 10       LUIS        174   @dominiodeemail.com
# 171  VALDEMIR         45   @dominiodeemail.com

# %%
nombres['email'] = nombres.nombre.str.cat(nombres.dominio).str.lower()
nombres.sample(5)
# Out:
#        nombre  id_alumno               dominio                        email
# 114      ELZA        320   @dominiodeemail.com      elza@dominiodeemail.com
# 57       IGOR        303  @serviciodeemail.com     igor@serviciodeemail.com
# 85   FABRICIO        221   @dominiodeemail.com  fabricio@dominiodeemail.com
# 183    MARLON          8   @dominiodeemail.com    marlon@dominiodeemail.com
# 189    WESLEI        137   @dominiodeemail.com    weslei@dominiodeemail.com

# %% [markdown]
# # Creando Cursos

# %%
import html5lib

# %%
url = 'https://www.tiobe.com/tiobe-index/'

# %%
cursos = pd.read_html(url)
cursos
# Out:
# [    Jan 2024  Jan 2023  Change  Programming Language Programming Language.1  \
#  0          1         1     NaN                   NaN                 Python
#  1          2         2     NaN                   NaN                      C
#  2          3         3     NaN                   NaN                    C++
#  3          4         4     NaN                   NaN                   Java
#  4          5         5     NaN                   NaN                     C#
#  5          6         7     NaN                   NaN             JavaScript
#  6          7        10     NaN                   NaN                    PHP
#  7          8         6     NaN                   NaN           Visual Basic
#  8          9         8     NaN                   NaN                    SQL
#  9         10        20     NaN                   NaN                Scratch
#  10        11        12     NaN                   NaN                     Go
#  11        12        27     NaN                   NaN                Fortran
#  12        13        17     NaN                   NaN   Delphi/Object Pascal
#  13        14        15     NaN                   NaN                 MATLAB
#  14        15         9     NaN                   NaN      Assembly language
#  15        16        11     NaN                   NaN                  Swift
#  16        17        25     NaN                   NaN                 Kotlin
#  17        18        16     NaN                   NaN                   Ruby
#  18        19        18     NaN                   NaN                   Rust
#  19        20        31     NaN                   NaN                  COBOL
#
#     Ratings Change.1
#  0   13.97%   -2.39%
#  1   11.44%   -4.81%
#  2    9.96%   -2.95%
#  3    7.87%   -4.34%
#  4    7.16%   +1.43%
#  5    2.77%   -0.11%
#  6    1.79%   +0.40%
#  7    1.60%   -3.04%
#  8    1.46%   -1.04%
#  9    1.44%   +0.86%
#  10   1.38%   +0.23%
#  11   1.09%   +0.64%
#  12   1.09%   +0.36%
#  13   0.97%   +0.06%
#  14   0.92%   -0.68%
#  15   0.89%   -0.31%
#  16   0.85%   +0.37%
#  17   0.80%   +0.01%
#  18   0.79%   +0.18%
#  19   0.78%   +0.45%  ,
#      Position  Programming Language Ratings
#  0         21                     D   0.77%
#  1         22                    F#   0.77%
#  2         23                     R   0.74%
#  3         24                   SAS   0.70%
#  4         25       (Visual) FoxPro   0.67%
#  5         26                   Ada   0.62%
#  6         27  Classic Visual Basic   0.60%
#  7         28                Prolog   0.56%
#  8         29              VBScript   0.55%
#  9         30                  Perl   0.52%
#  10        31           Objective-C   0.46%
#  11        32                  Dart   0.43%
#  12        33                 Julia   0.40%
#  13        34                   X++   0.39%
#  14        35            TypeScript   0.39%
#  15        36                   Lua   0.37%
#  16        37                 Scala   0.34%
#  17        38                  GAMS   0.33%
#  18        39          Transact-SQL   0.30%
#  19        40                  Logo   0.30%
#  20        41                  ABAP   0.29%
#  21        42                  Lisp   0.28%
#  22        43                  CFML   0.28%
#  23        44               Haskell   0.28%
#  24        45                PL/SQL   0.27%
#  25        46                   Awk   0.27%
#  26        47                Eiffel   0.24%
#  27        48             Smalltalk   0.23%
#  28        49                    ML   0.23%
#  29        50          ActionScript   0.23%,
#     Programming Language 2024 2019 2014 2009 2004 1999 1994 1989
#  0                Python    1    4    8    6   11   22   22    -
#  1                     C    2    2    1    2    2    1    1    1
#  2                   C++    3    3    4    3    3    2    2    3
#  3                  Java    4    1    2    1    1   16    -    -
#  4                    C#    5    6    5    8    9   32    -    -
#  5            JavaScript    6    8    9    9    8   21    -    -
#  6          Visual Basic    7   19    -    -    -    -    -    -
#  7                   PHP    8    7    6    5    6    -    -    -
#  8                   SQL    9    9    -    -    7    -    -    -
#  9     Assembly language   10   13    -    -    -    -    -    -
#  10          Objective-C   27   11    3   42   48    -    -    -
#  11                 Lisp   30   28   14   17   15   10    7    2
#  12       (Visual) Basic    -    -    7    4    5    3    3    7,
#      Year        Winner
#  0   2023            C#
#  1   2022           C++
#  2   2021        Python
#  3   2020        Python
#  4   2019             C
#  5   2018        Python
#  6   2017             C
#  7   2016            Go
#  8   2015          Java
#  9   2014    JavaScript
#  10  2013  Transact-SQL
#  11  2012   Objective-C
#  12  2011   Objective-C
#  13  2010        Python
#  14  2009            Go
#  15  2008             C
#  16  2007        Python
#  17  2006          Ruby
#  18  2005          Java
#  19  2004           PHP
#  20  2003           C++]

# %%
cursos = cursos[0]
cursos
# Out:
#     Jan 2024  Jan 2023  Change  Programming Language Programming Language.1  \
# 0          1         1     NaN                   NaN                 Python
# 1          2         2     NaN                   NaN                      C
# 2          3         3     NaN                   NaN                    C++
# 3          4         4     NaN                   NaN                   Java
# 4          5         5     NaN                   NaN                     C#
# 5          6         7     NaN                   NaN             JavaScript
# 6          7        10     NaN                   NaN                    PHP
# 7          8         6     NaN                   NaN           Visual Basic
# 8          9         8     NaN                   NaN                    SQL
# 9         10        20     NaN                   NaN                Scratch
# 10        11        12     NaN                   NaN                     Go
# 11        12        27     NaN                   NaN                Fortran
# 12        13        17     NaN                   NaN   Delphi/Object Pascal
# 13        14        15     NaN                   NaN                 MATLAB
# 14        15         9     NaN                   NaN      Assembly language
# 15        16        11     NaN                   NaN                  Swift
# 16        17        25     NaN                   NaN                 Kotlin
# 17        18        16     NaN                   NaN                   Ruby
# 18        19        18     NaN                   NaN                   Rust
# 19        20        31     NaN                   NaN                  COBOL
#
#    Ratings Change.1
# 0   13.97%   -2.39%
# 1   11.44%   -4.81%
# 2    9.96%   -2.95%
# 3    7.87%   -4.34%
# 4    7.16%   +1.43%
# 5    2.77%   -0.11%
# 6    1.79%   +0.40%
# 7    1.60%   -3.04%
# 8    1.46%   -1.04%
# 9    1.44%   +0.86%
# 10   1.38%   +0.23%
# 11   1.09%   +0.64%
# 12   1.09%   +0.36%
# 13   0.97%   +0.06%
# 14   0.92%   -0.68%
# 15   0.89%   -0.31%
# 16   0.85%   +0.37%
# 17   0.80%   +0.01%
# 18   0.79%   +0.18%
# 19   0.78%   +0.45%

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos.head()
# Out:
#    Jan 2024  Jan 2023  Change  Programming Language Programming Language.1  \
# 0         1         1     NaN                   NaN                 Python
# 1         2         2     NaN                   NaN                      C
# 2         3         3     NaN                   NaN                    C++
# 3         4         4     NaN                   NaN                   Java
# 4         5         5     NaN                   NaN                     C#
#
#   Ratings Change.1
# 0  13.97%   -2.39%
# 1  11.44%   -4.81%
# 2   9.96%   -2.95%
# 3   7.87%   -4.34%
# 4   7.16%   +1.43%

# %% [markdown]
# #Adicionando Index

# %%
cursos = cursos.rename(columns={'Programming Language.1':'nombre_cursos'})

# %%
cursos['id'] = cursos.index + 1
cursos
# Out:
#     Jan 2024  Jan 2023  Change  Programming Language         nombre_cursos  \
# 0          1         1     NaN                   NaN                Python
# 1          2         2     NaN                   NaN                     C
# 2          3         3     NaN                   NaN                   C++
# 3          4         4     NaN                   NaN                  Java
# 4          5         5     NaN                   NaN                    C#
# 5          6         7     NaN                   NaN            JavaScript
# 6          7        10     NaN                   NaN                   PHP
# 7          8         6     NaN                   NaN          Visual Basic
# 8          9         8     NaN                   NaN                   SQL
# 9         10        20     NaN                   NaN               Scratch
# 10        11        12     NaN                   NaN                    Go
# 11        12        27     NaN                   NaN               Fortran
# 12        13        17     NaN                   NaN  Delphi/Object Pascal
# 13        14        15     NaN                   NaN                MATLAB
# 14        15         9     NaN                   NaN     Assembly language
# 15        16        11     NaN                   NaN                 Swift
# 16        17        25     NaN                   NaN                Kotlin
# 17        18        16     NaN                   NaN                  Ruby
# 18        19        18     NaN                   NaN                  Rust
# 19        20        31     NaN                   NaN                 COBOL
#
#    Ratings Change.1  id
# 0   13.97%   -2.39%   1
# 1   11.44%   -4.81%   2
# 2    9.96%   -2.95%   3
# 3    7.87%   -4.34%   4
# 4    7.16%   +1.43%   5
# 5    2.77%   -0.11%   6
# 6    1.79%   +0.40%   7
# 7    1.60%   -3.04%   8
# 8    1.46%   -1.04%   9
# 9    1.44%   +0.86%  10
# 10   1.38%   +0.23%  11
# 11   1.09%   +0.64%  12
# 12   1.09%   +0.36%  13
# 13   0.97%   +0.06%  14
# 14   0.92%   -0.68%  15
# 15   0.89%   -0.31%  16
# 16   0.85%   +0.37%  17
# 17   0.80%   +0.01%  18
# 18   0.79%   +0.18%  19
# 19   0.78%   +0.45%  20

# %%
cursos = cursos.set_index('id')
cursos.head()
# Out:
#     Jan 2024  Jan 2023  Change  Programming Language nombre_cursos Ratings  \
# id
# 1          1         1     NaN                   NaN        Python  13.97%
# 2          2         2     NaN                   NaN             C  11.44%
# 3          3         3     NaN                   NaN           C++   9.96%
# 4          4         4     NaN                   NaN          Java   7.87%
# 5          5         5     NaN                   NaN            C#   7.16%
#
#    Change.1
# id
# 1    -2.39%
# 2    -4.81%
# 3    -2.95%
# 4    -4.34%
# 5    +1.43%

# %%
cursos.shape
# Out:
# (20, 7)

# %% [markdown]
# #Borrando columnas

# %%
columnas_a_borrar = ['Jan 2024', 'Jan 2023', 'Change', 'Programming Language','Ratings', 'Change.1']

# %%
cursos = cursos.drop(columns= columnas_a_borrar)

# %%
cursos.head()
# Out:
#    nombre_cursos
# id
# 1         Python
# 2              C
# 3            C++
# 4           Java
# 5             C#

# %% [markdown]
# #Matriculando Alumnos

# %%
nombres['matriculas'] = np.ceil(np.random.exponential(size=total_alumnos)*1.5).astype(int)
nombres.head()
# Out:
#       nombre  id_alumno               dominio                         email  \
# 0       JOSE        235   @dominiodeemail.com       jose@dominiodeemail.com
# 1       JOAO         43  @serviciodeemail.com      joao@serviciodeemail.com
# 2    ANTONIO        304  @serviciodeemail.com   antonio@serviciodeemail.com
# 3  FRANCISCO        156   @dominiodeemail.com  francisco@dominiodeemail.com
# 4     CARLOS        343  @serviciodeemail.com    carlos@serviciodeemail.com
#
#    matriculas
# 0           1
# 1           1
# 2           5
# 3           5
# 4           1

# %%
nombres.matriculas.describe()
# Out:
# count    400.000000
# mean       2.135000
# std        1.515757
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       12.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.displot(nombres.matriculas)

# %%
nombres.matriculas.value_counts()
# Out:
# 1     184
# 2      97
# 3      56
# 4      34
# 5      19
# 6       5
# 12      2
# 8       2
# 7       1
# Name: matriculas, dtype: int64

# %% [markdown]
# #Seleccionando Alumnos

# %%
nombres.head()
# Out:
#       nombre  id_alumno               dominio                         email  \
# 0       JOSE        235   @dominiodeemail.com       jose@dominiodeemail.com
# 1       JOAO         43  @serviciodeemail.com      joao@serviciodeemail.com
# 2    ANTONIO        304  @serviciodeemail.com   antonio@serviciodeemail.com
# 3  FRANCISCO        156   @dominiodeemail.com  francisco@dominiodeemail.com
# 4     CARLOS        343  @serviciodeemail.com    carlos@serviciodeemail.com
#
#    matriculas
# 0           1
# 1           1
# 2           5
# 3           5
# 4           1

# %%
todas_matriculas = []
x = np.random.rand(len(cursos))
prob = x / sum(x)
prob
# Out:
# array([1.01460985e-01, 1.53904716e-02, 5.13287407e-02, 2.55851615e-02,
#        9.24606206e-02, 5.02721714e-02, 1.68363077e-05, 3.25269333e-02,
#        2.51788181e-02, 9.25997751e-03, 6.57412117e-02, 4.17303042e-02,
#        2.71144488e-02, 1.16005269e-01, 4.00996179e-02, 1.58158450e-02,
#        6.47951453e-02, 1.10514998e-01, 9.63493484e-02, 1.83530957e-02])

# %%
for index , row in nombres.iterrows():
  id = row.id_alumno
  matriculas = row.matriculas
  for i in range(matriculas):
    mat = [id, np.random.choice(cursos.index, p = prob)]
    todas_matriculas.append(mat)

matriculas = pd.DataFrame(todas_matriculas,columns=['id_alumno','id_curso'])
matriculas.head()
# Out:
#    id_alumno  id_curso
# 0        235         6
# 1         43         5
# 2        304        19
# 3        304         5
# 4        304         4

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['nombre_cursos'])[['nombre_cursos','id_alumno']].rename(columns={'id_alumno' :'Total'}).sort_values('Total', ascending=False)
matriculas_por_curso
# Out:
#                  nombre_cursos  Total
# id_curso
# 14                      MATLAB    104
# 18                        Ruby    104
# 1                       Python     94
# 5                           C#     90
# 19                        Rust     72
# 17                      Kotlin     58
# 11                          Go     53
# 3                          C++     46
# 6                   JavaScript     44
# 12                     Fortran     37
# 15           Assembly language     30
# 8                 Visual Basic     24
# 4                         Java     24
# 16                       Swift     17
# 13        Delphi/Object Pascal     14
# 2                            C     12
# 20                       COBOL     12
# 9                          SQL     10
# 10                     Scratch      9

# %% [markdown]
# #Salida en diferente formatos

# %%
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index = False)

# %%
matriculas_por_curso.to_json('matriculas_por_curso.json')

# %%
matriculas_por_curso.to_html('matriculas_por_curso.html', index = False)

# %% [markdown]
# #Creando Banco SQL

# %%
from sqlalchemy import create_engine, MetaData, Table,inspect

# %%
engine = create_engine('sqlite:///:memory:')
engine
# Out:
# Engine(sqlite:///:memory:)

# %%
matriculas_por_curso.to_sql('matriculas',engine)
# Out:
# 19

# %%
metadata = MetaData()

# %%
metadata.reflect(bind=engine)

# %%
print(metadata.tables.keys())
# Out:
# dict_keys(['matriculas'])

# %% [markdown]
# #Buscando en Banco SQL

# %%
from sqlite3 import connect

# %%
conn = connect(':memory:')

# %%
matriculas_por_curso.to_sql(name='test_data',con=conn)
# Out:
# 19

# %%
query = 'select * from test_data where total <20'

# %%
pd.read_sql(query,conn)
# Out:
#    id_curso         nombre_cursos  Total
# 0        16                 Swift     17
# 1        13  Delphi/Object Pascal     14
# 2         2                     C     12
# 3        20                 COBOL     12
# 4         9                   SQL     10
# 5        10               Scratch      9

# %% [markdown]
# #Nombres para el Ingreso

# %%
matriculas.sample(5)
# Out:
#      id_alumno  id_curso
# 226         39        18
# 13         310        15
# 830         58         5
# 368         82         2
# 506        152        18

# %%
id_curso = 16
proximas_clase = matriculas.query('id_curso == {}'.format(id_curso))
proximas_clase

# %%
proximas_clase.set_index('id_alumno').join(nombres.set_index('id_alumno'))['nombre'].to_frame()
# Out:
#              nombre
# id_alumno
# 10          RODRIGO
# 38           ALVARO
# 49         LEONARDO
# 153           JAIME
# 153           JAIME
# 172        ANDERSON
# 212        HENRIQUE
# 251        CRISTINA
# 259         GERALDO
# 260         ROBERTA
# 306         GERALDA
# 315          LILIAN
# 336          JOSEFA
# 337          ANGELA
# 348        PRISCILA
# 363          GISELE
# 381           MAURO

# %%
nombre_aula = cursos.loc[id_curso]
nombre_aula
# Out:
# nombre_cursos    Swift
# Name: 16, dtype: object

# %%
nombre_aula = nombre_aula.nombre_cursos
nombre_aula
# Out:
# 'Swift'

# %%
proximas_clase = proximas_clase.set_index('id_alumno').join(nombres.set_index('id_alumno'))['nombre'].to_frame()

# %%
proximas_clase = proximas_clase.rename(columns = {'nombre' : 'Alumnos del curso de {}'.format(nombre_aula)})
proximas_clase.sample(5)
# Out:
#           Alumnos del curso de Swift
# id_alumno
# 38                            ALVARO
# 348                         PRISCILA
# 336                           JOSEFA
# 172                         ANDERSON
# 337                           ANGELA

# %% [markdown]
# #Excel

# %%
proximas_clase.to_excel('proxima_clase.xlsx',index = False)
